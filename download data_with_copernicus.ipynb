# %%
import pickle
import getpass, os
import numpy as np
import pandas as pd
os.environ['PSQL_USER']='infodenguedev'
os.environ['PSQL_HOST']='159.69.25.201'
os.environ['PSQL_DB']='dengue'
os.environ['PSQL_PORT']='5432'
os.environ['PSQL_PASSWORD']="infodenguedev"

# %%
import matplotlib.pyplot as plt
from upload_data import get_cluster_data, data_cop

# %% [markdown]
# Olhando apenas para os dados do copernicus:

# %%
df_rio = data_cop(2503308)

df_rio
# Out:
#              temp_min   temp_max   umid_min   umid_max  pressao_min  \
# date
# 1999-12-31  21.953949  31.481842  42.940120  97.110245     0.994230
# 2000-01-01  22.606903  33.094270  35.281700  84.589460     0.992641
# 2000-01-02  22.644806  33.985870  29.300728  87.335785     0.992451
# 2000-01-03  23.957092  33.610016  35.677536  81.569200     0.992015
# 2000-01-04  23.363007  29.425629  49.011677  82.555374     0.993911
# ...               ...        ...        ...        ...          ...
# 2023-04-22  22.245056  32.393340  44.745940  91.609390     0.994525
# 2023-04-23  20.474548  30.845612  47.819565  85.334076     0.996655
# 2023-04-24  22.072845  31.515533  47.942260  91.264540     0.997148
# 2023-04-25  22.435516  31.463257  52.465374  89.113440     0.998067
# 2023-04-26  23.659912  31.521637  52.480934  87.672325     0.997015
#
#             pressao_max
# date
# 1999-12-31     0.999366
# 2000-01-01     0.997483
# 2000-01-02     0.996811
# 2000-01-03     0.996974
# ...

# %%
df_rio.index.year.value_counts()
# Out:
# 2012    366
# 2000    366
# 2016    366
# 2020    366
# 2022    365
# 2021    365
# 2019    365
# 2010    365
# 2011    365
# 2013    365
# 2014    365
# 2015    365
# 2017    365
# 2018    365
# 2004    335
# 2005    306
# 2001    304
# 2002    276
# 2003    183
# 2023    116
# 2009     32
# 2008     28
# 2007     15
# 1999      1
# Name: date, dtype: int64

# %%
df_rio.columns[df_rio.isna().any()].tolist()
# Out:
# []

# %%
def get_table_data(city, state, cluster = False, doenca = 'dengue', data_types = ['alerta', 'weather'], 
    predictors = ['casos', 'casos_est', 'casos_est_min',
                                     'casos_est_max', 'p_rt1', 'p_inc100k', 'temp_min',
                                      'temp_max', 'umid_min', 'pressao_min'], temp = 'old'):

    with open(f'clusters/clusters_{state}.pkl', 'rb') as fp:
            clusters = pickle.load(fp)

    data, group = get_cluster_data(city, clusters=clusters, data_types= data_types, cols= predictors, doenca = doenca, temp = temp)   

    if cluster == False: 
        for i in data.columns:

            if i.endswith(f'{city}') == False:

                del data[i]
                
    return data

# %% [markdown]
# # Ceará

# %%
c = 2304400
e = 'CE'
df_d = get_table_data(c, e, cluster = True, doenca = 'dengue', temp = 'cop')
df_d.to_csv(f'./data/dengue_{c}_cluster.csv')

# %%
df_d.columns[df_d.isna().any()].tolist()
# Out:
# []

# %%
df_d
# Out:
#             casos_2307650  casos_est_2307650  casos_est_min_2307650  \
# 2010-01-03              2                2.0                      2
# 2010-01-10              3                3.0                      3
# 2010-01-17              6                6.0                      6
# 2010-01-24              4                4.0                      4
# 2010-01-31              5                5.0                      5
# ...                   ...                ...                    ...
# 2023-03-19             71               92.0                     74
# 2023-03-26             48               72.0                     52
# 2023-04-02             26               59.0                     32
# 2023-04-09             25               60.0                     29
# 2023-04-16              0               29.5                      2
#
#             casos_est_max_2307650  p_rt1_2307650  p_inc100k_2307650  \
# 2010-01-03                      2       0.000000           0.871619
# ...

# %%
df_c = get_table_data(c, e, cluster = True, doenca = 'chik', temp = 'cop')
df_c.to_csv(f'./data/chik_{c}_cluster.csv')

# %%
df_c.columns[df_c.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# # Paraíba

# %%
c = 2507507
e = 'PB'
df_d = get_table_data(c, e, cluster = True, doenca = 'dengue', temp = 'cop')
df_d.to_csv(f'./data/dengue_{c}_cluster.csv')

# %%
df_d
# Out:
#             casos_2511103  casos_est_2511103  casos_est_min_2511103  \
# 2010-01-03              0                0.0                      0
# 2010-01-10              0                0.0                      0
# 2010-01-17              0                0.0                      0
# 2010-01-24              0                0.0                      0
# 2010-01-31              0                0.0                      0
# ...                   ...                ...                    ...
# 2023-03-19              0                0.0                      0
# 2023-03-26              0                0.0                      0
# 2023-04-02              2                2.0                      2
# 2023-04-09              1                1.0                      1
# 2023-04-16              0                0.0                      0
#
#             casos_est_max_2511103  p_rt1_2511103  p_inc100k_2511103  \
# 2010-01-03                      0       0.000000            0.00000
# ...

# %%
df_d.columns[df_d.isna().any()].tolist()
# Out:
# []

# %%
df_d[['casos_2503308',
 'casos_est_2503308',
 'casos_est_min_2503308',
 'casos_est_max_2503308',
 'p_rt1_2503308',
 'p_inc100k_2503308',
 'temp_min_2503308',
 'temp_max_2503308',
 'umid_min_2503308',
 'pressao_min_2503308']
]
# Out:
#             casos_2503308  casos_est_2503308  casos_est_min_2503308  \
# 2010-01-03              0                0.0                      0
# 2010-01-10              0                0.0                      0
# 2010-01-17              0                0.0                      0
# 2010-01-24              0                0.0                      0
# 2010-01-31              0                0.0                      0
# ...                   ...                ...                    ...
# 2023-03-19              0                0.0                      0
# 2023-03-26              1                1.0                      1
# 2023-04-02              9                9.0                      9
# 2023-04-09              0                0.0                      0
# 2023-04-16              0                2.0                      0
#
#             casos_est_max_2503308  p_rt1_2503308  p_inc100k_2503308  \
# 2010-01-03                      0       0.000000           0.000000
# ...

# %%
df_c = get_table_data(c, e, cluster = True, doenca = 'chik', temp = 'cop')
df_c.to_csv(f'./data/chik_{c}_cluster.csv')

# %%
df_c.columns[df_c.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# # Pernambuco

# %%
c = 2611606
e = 'PE'
df_d = get_table_data(c, e, cluster = True, doenca = 'dengue', temp = 'cop')
df_d.to_csv(f'./data/dengue_{c}_cluster.csv')

# %%
df_d
# Out:
#             casos_2611606  casos_est_2611606  casos_est_min_2611606  \
# 2010-01-03              3                3.0                      3
# 2010-01-10              1                1.0                      1
# 2010-01-17              2                2.0                      2
# 2010-01-24              1                1.0                      1
# 2010-01-31              0                0.0                      0
# ...                   ...                ...                    ...
# 2023-03-19            138              207.0                    167
# 2023-03-26            103              187.0                    140
# 2023-04-02             71              169.0                    119
# 2023-04-09             69              177.0                    113
# 2023-04-16             12              140.0                     52
#
#             casos_est_max_2611606  p_rt1_2611606  p_inc100k_2611606  \
# 2010-01-03                      3       0.000000           0.181438
# ...

# %%
df_d.columns[df_d.isna().any()].tolist()
# Out:
# []

# %%
df_c = get_table_data(c, e, cluster = True, doenca = 'chik', temp = 'cop')
df_c.to_csv(f'./data/chik_{c}_cluster.csv')

# %%
df_c.columns[df_c.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# # Rio de Janeiro

# %%
c = 3304557
e = 'RJ'
df_d = get_table_data(c, e, cluster = True, doenca = 'dengue', temp = 'cop')
df_d.to_csv(f'./data/dengue_{c}_cluster.csv')

# %%
df_d
# Out:
#             casos_3304557  casos_est_3304557  casos_est_min_3304557  \
# 2010-01-03             31               31.0                     31
# 2010-01-10             45               45.0                     45
# 2010-01-17             48               48.0                     48
# 2010-01-24             56               56.0                     56
# 2010-01-31             69               69.0                     69
# ...                   ...                ...                    ...
# 2023-03-19           1301             1365.0                   1310
# 2023-03-26           1439             1556.0                   1452
# 2023-04-02           1205             1431.0                   1220
# 2023-04-09           1265             1773.0                   1281
# 2023-04-16            272             1712.5                    292
#
#             casos_est_max_3304557  p_rt1_3304557  p_inc100k_3304557  \
# 2010-01-03                   31.0       0.000000           0.459408
# ...

# %%
df_d.columns[df_d.isna().any()].tolist()
# Out:
# []

# %%
df_c = get_table_data(c, e, cluster = True, doenca = 'chik', temp = 'cop')
df_c.to_csv(f'./data/chik_{c}_cluster.csv')

# %%
df_c.columns[df_c.isna().any()].tolist()
# Out:
# []
