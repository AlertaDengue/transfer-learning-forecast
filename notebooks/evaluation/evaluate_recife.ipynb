# %%
import sys
import pickle
sys.path.append('../..')
from datetime import datetime 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse 
from comp_models import ss, conf_ss, plot_comp, conf_all_models, ss_all_models

# %%
CITY = 2611606
CITY_NAME = 'Recife'
STATE = 'PE'

# %% [markdown]
# There is some abreviations in this notebook:
# - **TL** refers to the transfer learning model;
# - **NN** refers to the Bi-LSTM model;
# - **ML** refers to the PGBM model;
# - **SS** refers to Skill Score.

# %% [markdown]
# ### Comp the predictions with loss = MSLE:

# %% [markdown]
# We will analyse these data between '2022-01-02' e '2022-05-08':

# %%
with open(f'../../predictions/lstm/lstm_{CITY}_chik_predictions_msle_all.pkl', 'rb') as f:
    data_nn = pickle.load(f)
    
doenca = 'dengue'
with open(f'../../predictions/pgbm/pgbm_{CITY}_chik_cross_predictions.pkl', 'rb') as f:
        data_ml = pickle.load(f)

with open(f'../../predictions/lstm/tl_{CITY}_transf_msle.pkl', 'rb') as f:
        data_tl = pickle.load(f)

# %%
ini_evaluate  = '2021-04-18'
end_evaluate = f'2021-08-15'

plot_comp(data_nn, data_ml, data_tl, ini_evaluate, end_evaluate)
# Out:
# RMSE - ML: 531.2541326898227
# RMSE - NN: 597.6883639655671
# RMSE - TL: 594.4157645905852

# %%
conf_all_models(data_nn, data_ml, data_tl, ini_evaluate, end_evaluate)
# Out:
# ---------------------------
# NN compared to ML:
# lower: -0.07667723265095994
# upper: 0.09976925341920084
# ---------------------------
# TL compared to NN:
# lower: 0.008605611783030542
# upper: 0.3168174205928954
# ---------------------------
# TL compared to ML:
# lower: -0.04248427036868896
# upper: 0.40871673674198106
# ---------------------------

# %%
plot_comp(data_nn, data_ml, data_tl, ini_evaluate, end_evaluate)
# Out:
# RMSE - ML: 531.2541326898227
# RMSE - NN: 597.6883639655671
# RMSE - TL: 594.4157645905852

# %%
conf_all_models(data_nn, data_ml, data_tl, ini_evaluate, end_evaluate)
# Out:
# ---------------------------
# NN compared to ML:
# lower: -0.07667723265095994
# upper: 0.09976925341920084
# ---------------------------
# TL compared to NN:
# lower: 0.008605611783030542
# upper: 0.3168174205928954
# ---------------------------
# TL compared to ML:
# lower: -0.04248427036868896
# upper: 0.40871673674198106
# ---------------------------

# %% [markdown]
# Let's see the value of SS by period:

# %%
INI_EVALUATE  = '2021-06-06'
END_EVALUATE = f'2021-07-11'

ss_all_models(data_nn, data_ml, data_tl, INI_EVALUATE, END_EVALUATE)
# Out:
# ---------------------------
# NN compared to ML:
# SS: -0.5956357769531073
# ---------------------------
# TL compared to NN:
# SS: -0.19165934073017654
# ---------------------------
# TL compared to ML:
# SS: -0.9014542780094228
# ---------------------------

# %%
INI_EVALUATE  = '2021-06-06'
END_EVALUATE = f'2021-08-08'

ss_all_models(data_nn, data_ml, data_tl, INI_EVALUATE, END_EVALUATE)
# Out:
# ---------------------------
# NN compared to ML:
# SS: -0.6485615131275071
# ---------------------------
# TL compared to NN:
# SS: -0.1597646441091214
# ---------------------------
# TL compared to ML:
# SS: -0.9119433565643182
# ---------------------------

# %%
INI_EVALUATE  = '2021-06-06'
END_EVALUATE = f'2021-09-05'

ss_all_models(data_nn, data_ml, data_tl, INI_EVALUATE, END_EVALUATE)
# Out:
# ---------------------------
# NN compared to ML:
# SS: -0.7966343158546594
# ---------------------------
# TL compared to NN:
# SS: -0.08170989286876296
# ---------------------------
# TL compared to ML:
# SS: -0.943437113327487
# ---------------------------

# %%
INI_EVALUATE  = '2021-06-06'
END_EVALUATE = f'2021-10-10'

ss_all_models(data_nn, data_ml, data_tl, INI_EVALUATE, END_EVALUATE)
# Out:
# ---------------------------
# NN compared to ML:
# SS: -0.7126225189965971
# ---------------------------
# TL compared to NN:
# SS: -0.08139885609611386
# ---------------------------
# TL compared to ML:
# SS: -0.8520280329673651
# ---------------------------
