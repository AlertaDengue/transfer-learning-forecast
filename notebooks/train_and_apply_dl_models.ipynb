# %%
from train_models import train_pgbm_dengue, apply_dengue_pgbm_on_chik, train_pgbm_chik
from train_models import train_dengue_model, train_chik_model, transf_and_pred_chik, apply_dl_dengue_on_chik
# Out:
# Using /Users/eduardoaraujo/Library/Caches/torch_extensions/py39_cpu as PyTorch extensions root...
# Emitting ninja build file /Users/eduardoaraujo/Library/Caches/torch_extensions/py39_cpu/split_decision/build.ninja...
# Building extension module split_decision...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module split_decision...
# Using /Users/eduardoaraujo/Library/Caches/torch_extensions/py39_cpu as PyTorch extensions root...
# No modifications detected for re-loaded extension module split_decision, skipping build step...
# Loading extension module split_decision...

# %%
city = 2611606
state = 'PE'
INI_DATE = '2014-10-01'
END_DATE_TRAIN = '2022-11-01'
END_DATE = '2023-11-01'

# %% [markdown]
# ### Train the dengue DL model:

# %%
# %%time 
train_dengue_model(city,  end_date_train = END_DATE_TRAIN , end_date = END_DATE)
# Out:
# Compilation Time :  0.0032167434692382812
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 121)]         0
#
#  bidirectional_1 (Bidirectio  (None, 52, 64)           95232
#  nal)
#
#  dropout_1 (Dropout)         (None, 52, 64)            0
#
#  lstm_1 (LSTM)               (None, 52, 64)            33024
#
#  dropout_2 (Dropout)         (None, 52, 64)            0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 4)                 260
#
# =================================================================
# Total params: 161,540
# Trainable params: 161,540
# Non-trainable params: 0
# _________________________________________________________________
# None
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# 2023-11-17 11:09:14.317326: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# CPU times: user 20min 17s, sys: 37.1 s, total: 20min 54s
# Wall time: 20min 34s

# %% [markdown]
# ### Apply this dengue DL model on chik data:

# %%
# %%time
apply_dl_dengue_on_chik(city, ini_date = INI_DATE, end_date_train = END_DATE_TRAIN , end_date = END_DATE)
# Out:
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# CPU times: user 9min 31s, sys: 6.96 s, total: 9min 38s
# Wall time: 9min 28s

# %% [markdown]
# ## Apply the transfer:

# %%
# %%time 

transf_and_pred_chik(city, ini_date = INI_DATE, end_date_train = END_DATE_TRAIN , end_date = END_DATE)
# Out:
# Compilation Time :  0.0017578601837158203
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 121)]         0
#
#  bidirectional_1 (Bidirectio  (None, 52, 64)           95232
#  nal)
#
#  dropout_1 (Dropout)         (None, 52, 64)            0
#
#  lstm_1 (LSTM)               (None, 52, 64)            33024
#
#  dropout_2 (Dropout)         (None, 52, 64)            0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 4)                 260
#
# =================================================================
# Total params: 161,540
# Trainable params: 161,540
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_train: (366, 52, 121)
# Epoch 1/250
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# 366/366 [==============================] - 21s 50ms/step - loss: 0.0199 - accuracy: 0.3087 - mape: 200.6753 - mse: 0.0052
# Epoch 2/250
# 366/366 [==============================] - 19s 52ms/step - loss: 0.0180 - accuracy: 0.3087 - mape: 168.4278 - mse: 0.0035
# Epoch 3/250
# 366/366 [==============================] - 19s 52ms/step - loss: 0.0182 - accuracy: 0.2951 - mape: 170.1306 - mse: 0.0051
# Epoch 4/250
# 366/366 [==============================] - 19s 53ms/step - loss: 0.0173 - accuracy: 0.3005 - mape: 149.3026 - mse: 0.0045
# Epoch 5/250
# 366/366 [==============================] - 19s 51ms/step - loss: 0.0167 - accuracy: 0.2978 - mape: 179.2822 - mse: 0.0042
# Epoch 6/250
# 366/366 [==============================] - 19s 51ms/step - loss: 0.0159 - accuracy: 0.3115 - mape: 152.3187 - mse: 0.0039
# Epoch 7/250
# 366/366 [==============================] - 19s 51ms/step - loss: 0.0149 - accuracy: 0.3251 - mape: 148.6588 - mse: 0.0025
# Epoch 8/250
# 366/366 [==============================] - 19s 51ms/step - loss: 0.0144 - accuracy: 0.3279 - mape: 146.6919 - mse: 0.0026
# Epoch 9/250
# 366/366 [==============================] - 19s 51ms/step - loss: 0.0140 - accuracy: 0.3251 - mape: 148.2801 - mse: 0.0026
# Epoch 10/250
# 366/366 [==============================] - 19s 51ms/step - loss: 0.0136 - accuracy: 0.3361 - mape: 150.8869 - mse: 0.0026
# Epoch 11/250
# 366/366 [==============================] - 19s 51ms/step - loss: 0.0129 - accuracy: 0.3279 - mape: 131.4242 - mse: 0.0023
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/Documents/Github/transfer-learning-forecast/notebooks/train_models.py:74, in transf_and_pred_chik(city, ini_date, end_date_train, end_date)
#      66 # apply transf model
#      67 m_msle, hist, m_t, m_val = transf_chik_pred(model, city, ini_date = ini_date, end_train_date = end_date_train,
#      68                                 end_date = end_date,  epochs= EPOCHS,
#      69                                 predict_n = PREDICT_N, look_back = LOOK_BACK, validation_split = 0.0, monitor = 'loss',
#      70                                   patience = 10, min_delta = 0.01/2,
#      71                                 label = f'transf_msle', ratio = None, filename_data = FILENAME_DATA,  verbose=1)
# ---> 74 plot_loss(hist, title = f'Model loss - MSLE - {city}')
#
# File ~/Documents/Github/transfer-learning-forecast/notebooks/../plots_lstm.py:164, in plot_loss(hist, title)
#     162 # "Loss"
#     163 P.plot(hist.history['loss'])
# --> 164 P.plot(hist.history['val_loss'])
#     165 P.title(f'{title}')
#     166 P.ylabel('loss')
#
# KeyError: 'val_loss'

# %% [markdown]
# ### Train the dengue pgbm model

# %%
# %%time
train_pgbm_dengue(city, state, ini_date = INI_DATE, end_date_train = END_DATE_TRAIN , end_date = END_DATE)
# Out:
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# CPU times: user 1h 3min 51s, sys: 1h 17min 39s, total: 2h 21min 30s
# Wall time: 41min 20s

# %% [markdown]
# ### Apply the dengue pgbm model on chik:

# %%
# %%time
apply_dengue_pgbm_on_chik(city, state, ini_date=INI_DATE, end_date= END_DATE)
# Out:
# (471,)
# (470,)
# (469,)
# (468,)
# CPU times: user 12.7 s, sys: 2.13 s, total: 14.8 s
# Wall time: 4.46 s

# %% [markdown]
# ### Train the chik DL model:

# %%
# %%time 

train_chik_model(city, ini_date = INI_DATE, end_date_train = END_DATE_TRAIN , end_date = END_DATE)
# Out:
# Compilation Time :  0.0017390251159667969
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 52, 376)]         0
#
#  bidirectional_1 (Bidirectio  (None, 52, 64)           225792
#  nal)
#
#  dropout_1 (Dropout)         (None, 52, 64)            0
#
#  lstm_1 (LSTM)               (None, 52, 64)            33024
#
#  dropout_2 (Dropout)         (None, 52, 64)            0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 4)                 260
#
# =================================================================
# Total params: 292,100
# Trainable params: 292,100
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/250
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# /Users/eduardoaraujo/Documents/Github/transfer-learning-forecast/notebooks/../preprocessing.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   norm_df[f'diff_{i}'] = np.concatenate(([np.nan], np.diff(norm_df[f'{i}'], 1)), axis = 0)
# 69/69 [==============================] - 9s 88ms/step - loss: 0.1323 - accuracy: 0.2226 - mape: 7337783.0000 - mse: 0.0204 - val_loss: 0.1170 - val_accuracy: 0.2935 - val_mape: 8624735.0000 - val_mse: 0.0017
# Epoch 2/250
# 69/69 [==============================] - 7s 95ms/step - loss: 0.1213 - accuracy: 0.2044 - mape: 10452615.0000 - mse: 0.0194 - val_loss: 0.1074 - val_accuracy: 0.1848 - val_mape: 17852078.0000 - val_mse: 0.0020
# Epoch 3/250
# 69/69 [==============================] - 7s 101ms/step - loss: 0.1107 - accuracy: 0.3613 - mape: 8528106.0000 - mse: 0.0177 - val_loss: 0.0977 - val_accuracy: 0.3152 - val_mape: 5513011.5000 - val_mse: 9.5324e-04
# Epoch 4/250
# 69/69 [==============================] - 7s 101ms/step - loss: 0
250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0096 - accuracy: 0.5255 - mape: 350055.8750 - mse: 0.0012 - val_loss: 0.0093 - val_accuracy: 0.5543 - val_mape: 38.2377 - val_mse: 4.0881e-04
# Epoch 82/250
# 69/69 [==============================] - 7s 101ms/step - loss: 0.0098 - accuracy: 0.5219 - mape: 560940.6875 - mse: 0.0017 - val_loss: 0.0091 - val_accuracy: 0.5543 - val_mape: 38.6269 - val_mse: 2.4889e-04
# Epoch 83/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0096 - accuracy: 0.5146 - mape: 658366.0000 - mse: 0.0016 - val_loss: 0.0090 - val_accuracy: 0.5543 - val_mape: 37.8800 - val_mse: 3.2260e-04
# Epoch 84/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0091 - accuracy: 0.5219 - mape: 222588.2656 - mse: 8.9693e-04 - val_loss: 0.0087 - val_accuracy: 0.4783 - val_mape: 1658662.7500 - val_mse: 2.5603e-04
# Epoch 85/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0089 - accuracy: 0.5401 - mape: 537620.5000 - mse: 8.9540e-04 - val_loss: 0.0087 - val_accuracy: 0.5543 - val_mape: 37.2325 - val_mse: 2.7312e-04
# Epoch 86/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0090 - accuracy: 0.5219 - mape: 273028.2188 - mse: 0.0013 - val_loss: 0.0086 - val_accuracy: 0.4891 - val_mape: 1210040.6250 - val_mse: 2.9296e-04
# Epoch 87/250
# 69/69 [==============================] - 7s 101ms/step - loss: 0.0092 - accuracy: 0.4854 - mape: 483215.3125 - mse: 0.0021 - val_loss: 0.0089 - val_accuracy: 0.4565 - val_mape: 7501833.0000 - val_mse: 6.4553e-04
# Epoch 88/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0087 - accuracy: 0.5073 - mape: 863588.0625 - mse: 8.7866e-04 - val_loss: 0.0084 - val_accuracy: 0.5652 - val_mape: 37.8763 - val_mse: 3.8840e-04
# Epoch 89/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0084 - accuracy: 0.5365 - mape: 226251.1875 - mse: 8.1161e-04 - val_loss: 0.0082 - val_accuracy: 0.5435 - val_mape: 155577.6250 - val_mse: 2.9055e-04
# Epoch 90/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0084 - accuracy: 0.5255 - mape: 519328.6875 - mse: 0.0011 - val_loss: 0.0081 - val_accuracy: 0.5543 - val_mape: 37.6444 - val_mse: 1.8498e-04
# Epoch 91/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0084 - accuracy: 0.5401 - mape: 194442.9219 - mse: 0.0012 - val_loss: 0.0080 - val_accuracy: 0.5543 - val_mape: 395246.0000 - val_mse: 3.8950e-04
# Epoch 92/250
# 69/69 [==============================] - 7s 100ms/step - loss: 0.0086 - accuracy: 0.5182 - mape: 222278.7344 - mse: 0.0017 - val_loss: 0.0082 - val_accuracy: 0.4674 - val_mape: 2506898.2500 - val_mse: 5.2855e-04
# Epoch 93/250
# 69/69 [==============================] - 7s 99ms/step - loss: 0.0093 - accuracy: 0.5146 - mape: 1700450.6250 - mse: 0.0031 - val_loss: 0.0095 - val_accuracy: 0.5326 - val_mape: 40.4891 - val_mse: 0.0017
# CPU times: user 18min 9s, sys: 1min 27s, total: 19min 37s
# Wall time: 18min 13s

# %% [markdown]
# ### Train the chik PGBM model:

# %%
# %%time
train_pgbm_chik(city, state, ini_date = INI_DATE, end_date_train = END_DATE_TRAIN , end_date = END_DATE)
# Out:
# Training on CPU
# Training on CPU
# Training on CPU
