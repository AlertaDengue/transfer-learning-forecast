# %%
import sys
import pickle
sys.path.append('../..')
from datetime import datetime 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse 
from comp_models import ss, conf_ss, plot_comp, conf_all_models, ss_all_models

# %%
CITY = 3304557
CITY_NAME = 'Rio de Janeiro'
STATE = 'RJ'

# %% [markdown]
# There is some abreviations in this notebook:
# - **TL** refers to the transfer learning model;
# - **NN** refers to the Bi-LSTM model;
# - **ML** refers to the PGBM model;
# - **SS** refers to Skill Score.

# %% [markdown]
# ### Comp the predictions with loss = MSLE:

# %% [markdown]
# We will analyse these data between '2022-01-02' e '2022-05-08':

# %%
with open(f'../../predictions/lstm/lstm_{CITY}_chik_predictions_msle_all.pkl', 'rb') as f:
    data_nn = pickle.load(f)
    
doenca = 'dengue'
with open(f'../../predictions/pgbm/pgbm_{CITY}_chik_cross_predictions.pkl', 'rb') as f:
        data_ml = pickle.load(f)

with open(f'../../predictions/lstm/tl_{CITY}_transf_msle.pkl', 'rb') as f:
        data_tl = pickle.load(f)

# %%
ini_evaluate  = '2019-01-06'
end_evaluate = f'2019-05-05'

plot_comp(data_nn, data_ml, data_tl, ini_evaluate, end_evaluate)

# %%
conf_all_models(data_nn, data_ml, data_tl, ini_evaluate, end_evaluate)
# Out:
# ---------------------------
# NN compared to ML:
# lower: -0.810147497477266
# upper: 0.6627406464702087
# ---------------------------
# TL compared to NN:
# lower: 0.24840809998989122
# upper: 0.6324697827636249
# ---------------------------
# TL compared to ML:
# lower: 0.06607850426416051
# upper: 0.8304747670183892
# ---------------------------

# %% [markdown]
# ### Comp the predictions with the CUSTOM_MSLE:

# %%
with open(f'../../predictions/lstm/lstm_{CITY}_chik_predictions_custom_msle_all.pkl', 'rb') as f:
    data_nn = pickle.load(f)
    
doenca = 'dengue'
with open(f'../../predictions/pgbm/pgbm_{CITY}_chik_cross_predictions.pkl', 'rb') as f:
        data_ml = pickle.load(f)
        
with open(f'../../predictions/lstm/tl_{CITY}_transf_custom_msle.pkl', 'rb') as f:
        data_tl = pickle.load(f)

# %%
plot_comp(data_nn, data_ml, data_tl, ini_evaluate, end_evaluate)

# %%
conf_all_models(data_nn, data_ml, data_tl, ini_evaluate, end_evaluate)
# Out:
# ---------------------------
# NN compared to ML:
# lower: -1.5314969521739146
# upper: 0.5086382951453469
# ---------------------------
# TL compared to NN:
# lower: -0.02010745507830758
# upper: 0.30928688779675684
# ---------------------------
# TL compared to ML:
# lower: -0.6460130808041025
# upper: 0.6383762065370449
# ---------------------------

# %% [markdown]
# Let's see the value of SS by period:

# %%
INI_EVALUATE  = '2019-01-06'
END_EVALUATE = f'2019-02-10'

ss_all_models(data_nn, data_ml, data_tl, INI_EVALUATE, END_EVALUATE)
# Out:
# ---------------------------
# NN compared to ML:
# SS: 0.7068622105476089
# ---------------------------
# TL compared to NN:
# SS: -0.00040509462701954213
# ---------------------------
# TL compared to ML:
# SS: 0.7067434620041253
# ---------------------------

# %%
INI_EVALUATE  = '2019-01-06'
END_EVALUATE = f'2019-03-10'

ss_all_models(data_nn, data_ml, data_tl, INI_EVALUATE, END_EVALUATE)
# Out:
# ---------------------------
# NN compared to ML:
# SS: 0.6884171002627311
# ---------------------------
# TL compared to NN:
# SS: -0.029961903387333733
# ---------------------------
# TL compared to ML:
# SS: 0.6790814835236576
# ---------------------------

# %%
INI_EVALUATE  = '2019-01-06'
END_EVALUATE = f'2019-04-07'

ss_all_models(data_nn, data_ml, data_tl, INI_EVALUATE, END_EVALUATE)
# Out:
# ---------------------------
# NN compared to ML:
# SS: 0.3330576869014813
# ---------------------------
# TL compared to NN:
# SS: 0.10060539981491101
# ---------------------------
# TL compared to ML:
# SS: 0.40015568496423937
# ---------------------------

# %%
INI_EVALUATE  = '2019-01-06'
END_EVALUATE = f'2019-05-05'

ss_all_models(data_nn, data_ml, data_tl, INI_EVALUATE, END_EVALUATE)
# Out:
# ---------------------------
# NN compared to ML:
# SS: -0.03329167738494876
# ---------------------------
# TL compared to NN:
# SS: 0.2430193285038148
# ---------------------------
# TL compared to ML:
# SS: 0.21781817220172195
# ---------------------------
